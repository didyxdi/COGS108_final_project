# %% [markdown]
# # A Pleasent Flight
#  Historical Air Crash + Delay Investigation

# %% [markdown]
# Unfortunely, there were many aviation accidents that caused innocent people to perish. While lessons we learnt in the past tragedy have made flying now more and more safer, the figures of planes falling from the sky still frightens a few people from having a pleasent flight. In this data analysis, we are going persuade thoes who are afraid by to investigate how safe are planes and, if one is still concerned, how to maximize one's safety? To make our report also interesting to general public, we will also investigate how one can minimize delays.

# %%
import pandas as pd
import numpy as np
from numpy import nan as Nan
import matplotlib.pyplot as plt
import requests

import xml.etree.ElementTree as ET # to read one dataset in XML format

# %% [markdown]
# ## Clean Air Crash Data

# %%
crash_df = pd.read_csv("datasets/crash/Airplane_Crashes_and_Fatalities_Since_1908.csv")
etree = ET.parse("datasets/crash/AviationData.xml")

# %% [markdown]
# load data
#
# select business flights whose enginetype is not reciprocating

# %%
xml_root = etree.getroot()

interest_columns = ["EventId","EventDate","Location","Country","Latitude","Longitude","AirportCode","InjurySeverity","AircraftDamage",
                    "AircraftCategory","NumberOfEngines","EngineType","Schedule","TotalUninjured","TotalMinorInjuries",
                    "TotalSeriousInjuries","TotalFatalInjuries","WeatherCondition","BroadPhaseOfFlight","RegistrationNumber","PurposeOfFlight"]

NTSB_crash_df = pd.DataFrame(columns=interest_columns) # NTSB_crash_df: dataframe which collects airport information. -- YD 02/28/2020

# %%
for elem in xml_root: # This loop will run only once
    for row in elem: 
        if not(row.attrib["PurposeOfFlight"]=="Business"):  # Only care about business flights whose engine type is not 'Reciprocating'-- YD 02/28/2020
            continue
        if row.attrib["EngineType"]=="Reciprocating": 
            continue
        information = list()
        for interest in interest_columns:
            if not (row.attrib[interest]==""):
                information.append(row.attrib[interest])
            else:
                information.append(np.nan)
        row_information = pd.Series(information,index=interest_columns)
        NTSB_crash_df = NTSB_crash_df.append(row_information,ignore_index=True)
            
# this may need to run for a while. It takes 18 seconds on my computer
NTSB_crash_df
# Out:
#             EventId   EventDate           Location        Country   Latitude  \
# 0    20200128X02229  01/22/2020          Minot, ND  United States  48.232223
# 1    20191031X31506  10/31/2019  New Braunfels, TX  United States  29.705833
# 2    20191019X04853  10/19/2019    Albuquerque, NM  United States  35.084444
# 3    20191021X62154  10/16/2019        Augusta, GA  United States  33.371945
# 4    20191005X82852  10/05/2019         Kokomo, IN  United States  40.475000
# ..              ...         ...                ...            ...        ...
# 830  20020917X02196  03/12/1982          CHINO, CA  United States        NaN
# 831  20020917X01930  03/01/1982           ALMA, CO  United States        NaN
# 832  20020917X01727  02/16/1982    SPRINGFIELD, KY  United States        NaN
# 833  20020917X01923  02/03/1982         HAYDEN, CO  United States        NaN
# 834  20020917X02157  01/06/1982  MAMMOTH LAKES, CA  United States        NaN
#
#        Longitude AirportCode InjurySeverity AircraftDamage AircraftCategory  \
# 0    -101.293333        2ND4      Non-Fatal    Substantial       Helicopter
# 1     -98.043333         BAZ      Non-Fatal          Minor         Airplane
# 2    -106.650278         NaN      Non-Fatal    Substantial          Balloon
# 3     -81.971667         AGS      Non-Fatal            NaN         Airplane
# 4     -86.063333         OKK       Fatal(1)      Destroyed         Airplane
# ..           ...         ...            ...            ...              ...
# 830          NaN         CNO      Non-Fatal    Substantial         Airplane
# 831          NaN         NaN      Non-Fatal    Substantial       Helicopter
# 832          NaN         6I2       Fatal(8)      Destroyed         Airplane
# 833          NaN         HDN      Non-Fatal      Destroyed         Airplane
# 834          NaN         MMH      Non-Fatal    Substantial       Helicopter
#
#      ...   EngineType Schedule TotalUninjured TotalMinorInjuries  \
# 0    ...  Turbo Shaft      NaN              1                NaN
# 1    ...          NaN      NaN              1                NaN
# 2    ...         None      NaN             13                NaN
# 3    ...    Turbo Fan      NaN            NaN                NaN
# 4    ...          NaN      NaN            NaN                NaN
# ..   ...          ...      ...            ...                ...
# 830  ...    Turbo Jet      NaN              2                  0
# 831  ...  Turbo Shaft      NaN              2                  0
# 832  ...   Turbo Prop      NaN              0                  0
# 833  ...   Turbo Prop      NaN              0                  6
# 834  ...  Turbo Shaft      NaN              6                  0
#
#     TotalSeriousInjuries TotalFatalInjuries WeatherCondition  \
# 0                    NaN                NaN              VMC
# 1                      1                NaN              VMC
# 2                    NaN                NaN              VMC
# 3                      1                NaN              VMC
# 4                    NaN                  1              VMC
# ..                   ...                ...              ...
# 830                    0                  0              VMC
# 831                    0                  0              VMC
# 832                    0                  8              IMC
# 833                    0                  0              IMC
# 834                    0                  0              VMC
#
#     BroadPhaseOfFlight RegistrationNumber PurposeOfFlight
# 0              LANDING             N947LH        Business
# 1                  NaN             N850BK        Business
# 2              LANDING             N275WB        Business
# 3                 TAXI             N307KP        Business
# 4          MANEUVERING             N326CW        Business
# ..                 ...                ...             ...
# 830            LANDING             N479CC        Business
# 831             CRUISE              N580P        Business
# 832           APPROACH             N2517X        Business
# 833            LANDING             N149JA        Business
# 834               TAXI             N608RA        Business
#
# [835 rows x 21 columns]

# %% [markdown]
# select all events with valid airport code

# %%
cities_need_df = pd.read_csv('cities_need.csv')
# cities_need_df

# %%
NTSB_crash_df['CheckAirportCode'] = NTSB_crash_df['AirportCode'].isin(cities_need_df['AirportCode'])
NTSB_crash_df = NTSB_crash_df[NTSB_crash_df['CheckAirportCode'] == True]
NTSB_crash_df
# Out:
#             EventId   EventDate         Location        Country   Latitude  \
# 3    20191021X62154  10/16/2019      Augusta, GA  United States  33.371945
# 5    20191003X13056  10/03/2019      Lansing, MI  United States  42.780278
# 26   20181130X80724  11/30/2018        Fargo, ND  United States  46.920556
# 57   20170228X14333  02/27/2017   Bellingham, WA  United States  48.791944
# 58   20170222X75136  02/20/2017  Albuquerque, NM  United States  35.064722
# ..              ...         ...              ...            ...        ...
# 801  20001214X42006  01/20/1983      LUBBOCK, TX  United States        NaN
# 806  20020917X04375  12/14/1982     COLUMBIA, SC  United States        NaN
# 812  20020917X04497  09/12/1982       HAYDEN, CO  United States        NaN
# 818  20020917X03513  08/16/1982      EL PASO, TX  United States        NaN
# 833  20020917X01923  02/03/1982       HAYDEN, CO  United States        NaN
#
#        Longitude AirportCode InjurySeverity AircraftDamage AircraftCategory  \
# 3     -81.971667         AGS      Non-Fatal            NaN         Airplane
# 5     -84.606111         LAN       Fatal(5)    Substantial         Airplane
# 26    -96.815833         FAR      Non-Fatal    Substantial         Airplane
# 57   -122.534722         BLI      Non-Fatal    Substantial         Airplane
# 58   -106.628056         ABQ      Non-Fatal    Substantial          Balloon
# ..           ...         ...            ...            ...              ...
# 801          NaN         LBB      Non-Fatal    Substantial              NaN
# 806          NaN         CAE      Non-Fatal    Substantial         Airplane
# 812          NaN         HDN       Fatal(6)      Destroyed         Airplane
# 818          NaN         ELP       Incident          Minor         Airplane
# 833          NaN         HDN      Non-Fatal      Destroyed         Airplane
#
#      ... Schedule TotalUninjured TotalMinorInjuries TotalSeriousInjuries  \
# 3    ...      NaN            NaN                NaN                    1
# 5    ...      NaN            NaN                NaN                    1
# 26   ...      NaN              2                  9                  NaN
# 57   ...      NaN              1                NaN                  NaN
# 58   ...      NaN             10                NaN                  NaN
# ..   ...      ...            ...                ...                  ...
# 801  ...      NaN              2                  0                    0
# 806  ...      NaN              2                  0                    0
# 812  ...      NaN              0                  0                    0
# 818  ...      NaN              0                  1                    0
# 833  ...      NaN              0                  6                    0
#
#     TotalFatalInjuries WeatherCondition BroadPhaseOfFlight RegistrationNumber  \
# 3                  NaN              VMC               TAXI             N307KP
# 5                    5              IMC           APPROACH             N700AQ
# 26                 NaN              IMC           APPROACH             N941JM
# 57                 NaN              IMC            TAKEOFF              CGWVS
# 58                 NaN              VMC           APPROACH             N709TC
# ..                 ...              ...                ...                ...
# 801                  0              IMC            LANDING             N555CH
# 806                  0              VMC            LANDING             N522MA
# 812                  6              VMC            TAKEOFF               N66U
# 818                  0              VMC            DESCENT             N1969J
# 833                  0              IMC            LANDING             N149JA
#
#     PurposeOfFlight CheckAirportCode
# 3          Business             True
# 5          Business             True
# 26         Business             True
# 57         Business             True
# 58         Business             True
# ..              ...              ...
# 801        Business             True
# 806        Business             True
# 812        Business             True
# 818        Business             True
# 833        Business             True
#
# [109 rows x 22 columns]

# %% [markdown]
# delete unrelated columns

# %%
NTSB_crash_df = NTSB_crash_df.drop(columns = ['EventId', 'EventDate', 'Location', 'Country', 'Latitude', 'Longitude', 'Schedule', 'RegistrationNumber', 'PurposeOfFlight', 'CheckAirportCode'])
NTSB_crash_df = NTSB_crash_df.reset_index(drop = True)
NTSB_crash_df
# Out:
#     AirportCode InjurySeverity AircraftDamage AircraftCategory  \
# 0           AGS      Non-Fatal            NaN         Airplane
# 1           LAN       Fatal(5)    Substantial         Airplane
# 2           FAR      Non-Fatal    Substantial         Airplane
# 3           BLI      Non-Fatal    Substantial         Airplane
# 4           ABQ      Non-Fatal    Substantial          Balloon
# ..          ...            ...            ...              ...
# 104         LBB      Non-Fatal    Substantial              NaN
# 105         CAE      Non-Fatal    Substantial         Airplane
# 106         HDN       Fatal(6)      Destroyed         Airplane
# 107         ELP       Incident          Minor         Airplane
# 108         HDN      Non-Fatal      Destroyed         Airplane
#
#     NumberOfEngines  EngineType TotalUninjured TotalMinorInjuries  \
# 0                 2   Turbo Fan            NaN                NaN
# 1                 1  Turbo Prop            NaN                NaN
# 2                 2   Turbo Jet              2                  9
# 3                 1  Turbo Prop              1                NaN
# 4               NaN         NaN             10                NaN
# ..              ...         ...            ...                ...
# 104               2  Turbo Prop              2                  0
# 105               2  Turbo Prop              2                  0
# 106               2  Turbo Prop              0                  0
# 107               2  Turbo Prop              0                  1
# 108               2  Turbo Prop              0                  6
#
#     TotalSeriousInjuries TotalFatalInjuries WeatherCondition  \
# 0                      1                NaN              VMC
# 1                      1                  5              IMC
# 2                    NaN                NaN              IMC
# 3                    NaN                NaN              IMC
# 4                    NaN                NaN              VMC
# ..                   ...                ...              ...
# 104                    0                  0              IMC
# 105                    0                  0              VMC
# 106                    0                  6              VMC
# 107                    0                  0              VMC
# 108                    0                  0              IMC
#
#     BroadPhaseOfFlight
# 0                 TAXI
# 1             APPROACH
# 2             APPROACH
# 3              TAKEOFF
# 4             APPROACH
# ..                 ...
# 104            LANDING
# 105            LANDING
# 106            TAKEOFF
# 107            DESCENT
# 108            LANDING
#
# [109 rows x 12 columns]

# %% [markdown]
# Standardize data

# %%
# This function deletes appended number behind data, blank spaces, parenthesis and lower case all letters -- YD 02/28/2020
# e.g. Fatal(10) --> fatal
def standarize_DeleteAppendedNumber(data_str):
    out=""
    for i in range(len(data_str)):
        if data_str[i] == " " or data_str[i] == "(" or data_str[i] == ")":
            continue
        elif data_str[i].isnumeric():
            continue
        else:
            out += data_str[i].lower()
    return out

# %%
NTSB_crash_df['InjurySeverity'] = NTSB_crash_df['InjurySeverity'].apply(standarize_DeleteAppendedNumber)

# %%
# NTSB_crash_df['InjurySeverity'].value_counts()
# Out:
# non-fatal    74
# incident     18
# fatal        17
# Name: InjurySeverity, dtype: int64

# %% [markdown]
# EDA
